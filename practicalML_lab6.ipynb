# %% [markdown]
# [CINTO4003U.LA_F23 (Artificial Intelligence and Machine Learning)](https://cbscanvas.instructure.com/courses/32010) - Copenhagen Business School<br>
# ***
# <br>
#
# #### Practical ML - Lab 6
# ### **Automated EDA using ydata-profiling**<br><br>
#
# [Exploratory data analysis](https://www.ibm.com/topics/exploratory-data-analysis) (EDA) is an important part of data analytics and data science. It is consider an axiomatic step in machine learning experimentation. In essence, it is the insights from your EDA, that decides all later choices regarding feature selection, data mining, learning algorithm selection, evaluation etc. However, the process of EDA can also be very time-consuming and repetitive.
#
# Wouldn't it be awesome if we could automate parts of it? This is where [ydata-profiling](https://github.com/ydataai/ydata-profiling) (`formerly, pandas-profiling`) comes in. The primary goal of ydata-profiling is to provide a one-line Exploratory Data Analysis (EDA) experience in a consistent and fast solution. Like pandas' `df.describe()` function, that is so handy, ydata-profiling delivers an extended analysis of a DataFrame while allowing the data analysis to be exported in different formats such as html and json.

# %% [markdown]
# Below we run through an example of using ydata-profiling with pandas on a tabular dataset.
#
# **NOTE**: If you can't get this to work, here is an example of the kind of report we are building with ydata-profiling: https://ydata-profiling.ydata.ai/examples/master/meteorites/meteorites_report.html

# %%
# Make sure you are in the virtual environment you want to be in!
# !pip install -U ydata-profiling
# !pip install -U ipywidgets
# Out:
# Requirement already satisfied: ydata-profiling in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (4.1.0)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (1.9.3)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (1.5.3)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (3.6.3)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (1.10.5)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (3.1.2)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (0.7.5)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (1.23.5)
# Requirement already satisfied: htmlmin==0.1.12 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (0.12.3)
# Requirement already satisfied: requests<2.29,>=2.24.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (2.28.2)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (4.64.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (0.12.2)
# Requirement already satisfied: multimethod<1.10,>=1.4 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (1.9.1)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (0.13.5)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (2.13.3)
# Requirement already satisfied: imagehash==4.3.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: PyWavelets in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling) (1.4.1)
# Requirement already satisfied: pillow in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from imagehash==4.3.1->ydata-profiling) (9.4.0)
# Requirement already satisfied: attrs>=19.3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (22.2.0)
# Requirement already satisfied: networkx>=2.4 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (3.0)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from pandas!=1.4.0,<1.6,>1.1->ydata-profiling) (2022.7.1)
# Requirement already satisfied: joblib>=0.14.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling) (4.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from requests<2.29,>=2.24.0->ydata-profiling) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from requests<2.29,>=2.24.0->ydata-profiling) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from requests<2.29,>=2.24.0->ydata-profiling) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from requests<2.29,>=2.24.0->ydata-profiling) (2022.12.7)
# Requirement already satisfied: patsy>=0.5.2 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling) (0.5.3)
# Requirement already satisfied: six in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->ydata-profiling) (1.16.0)
# Requirement already satisfied: ipywidgets in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (8.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipywidgets) (6.20.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipywidgets) (8.8.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipywidgets) (5.8.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: appnope in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.0)
# Requirement already satisfied: psutil in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.4)
# Requirement already satisfied: pyzmq>=17 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.0.0)
# Requirement already satisfied: tornado>=6.1 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: backcall in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pickleshare in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.14.0)
# Requirement already satisfied: stack-data in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: entrypoints in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/aiml-labs/lib/python3.11/site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.6.2)

# %%
import pandas as pd
import ydata_profiling

# %%
URL = "https://data.nasa.gov/api/views/gh4g-9sfh/rows.csv?accessType=DOWNLOAD"
df = pd.read_csv(URL)
df.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %%
report = df.profile_report(
    sort=None,
    html={"style": {"full_width": True}}, 
    progress_bar=True, 
    explorative=True
)

# %%
# renders it in the notebook
report

# %% [markdown]
# That's it! You now have an interactive report of your dataset as a starting point for your EDA! <br>
# Check out [the documentation for ydata-profiling](https://ydata-profiling.ydata.ai/docs/master/index.html) for more info about how take full advantage of the tools, and how to save the report to .html, .json etc.
